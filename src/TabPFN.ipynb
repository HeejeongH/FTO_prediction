# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import mutual_info_classif, RFE
import shap
from tabpfn import TabPFNClassifier
from tabpfn.constants import ModelVersion
from sklearn.metrics import f1_score, roc_auc_score
import os
import warnings
warnings.filterwarnings('ignore')

from sklearn.decomposition import PCA
from sklearn.feature_selection import mutual_info_classif
from sklearn.metrics import f1_score, roc_auc_score
from tqdm.notebook import tqdm
import time

import huggingface_hub
huggingface_hub.login()

# %%
selected_descriptor = pd.read_csv('../data/descriptor_selection.csv')

file_md_list = {}
for column in selected_descriptor.columns:
    filename = column
    selected_columns = selected_descriptor[column].iloc[0:].dropna().tolist()
    if filename and selected_columns:
        file_md_list[filename] = selected_columns

data_dir = os.path.join("..", "data", "preprocessed")
result_dir = os.path.join("..", "result", "FTO_TABPFN")
os.makedirs(result_dir, exist_ok=True)

# %%
ratio = '10x'
results = {}

file_name = f'descriptors_filtered_FTO_training_{ratio}_ignore3D_False.csv'
data_path = os.path.join(data_dir, f"filtered_FTO_training_{ratio}_ignore3D_False.csv")

df = pd.read_csv(data_path)

md_cols = file_md_list[file_name]
fp_cols = [f'X{i+1}' for i in range(1024)]
filtered_df = df[['potency'] + fp_cols + md_cols]

X = filtered_df.drop('potency', axis=1)
Y = filtered_df['potency']

X_train, X_test, y_train, y_test = train_test_split( X, Y, test_size=0.1, random_state=42, stratify=Y)

print(f'현재 변수 갯수: {len(X_train.columns)}')
print(f'  - Fingerprint: {len(fp_cols)}개')
print(f'  - Molecular Descriptor: {len(md_cols)}개')
# Out:
# 현재 변수 갯수: 1040
#   - Fingerprint: 1024개
#   - Molecular Descriptor: 16개

# %% [markdown]
# # 기존 Pycaret 결과

# %%
comparison_list = []

# PyCaret Blend 결과
pycaret_blend_path = f"../result/FTO_Final/{ratio}_w3D/{ratio}_blend_final_metrics.csv"
blend_metrics = pd.read_csv(pycaret_blend_path)
comparison_list.append(pd.DataFrame({
    'method': ['Blend (PyCaret)'],
    'f1': [blend_metrics['F1'].iloc[0]],
    'auc': [blend_metrics['AUC'].iloc[0]],
    'n_features': [len(X_train.columns)]
}))
        
# PyCaret 개별 모델 결과
pycaret_summary_path = f"../result/FTO_Final/{ratio}_w3D/{ratio}_summary_evaluation.csv"
summary_df = pd.read_csv(pycaret_summary_path)
mean_df = summary_df[summary_df['Type'] == 'Mean'].copy()

for _, row in mean_df.iterrows():
    comparison_list.append(pd.DataFrame({
        'method': [f"{row['Model']} (PyCaret)"],
        'f1': [row['F1']],
        'auc': [row['AUC']],
        'n_features': [len(X_train.columns)]
        }))

final_comparison_df = pd.concat(comparison_list, ignore_index=True)

# %% [markdown]
# # TabPFN 모델 실험

# %%
n_features_list = [50, 100, 200, 300, 400, 500]
feature_methods = ['all', 'random', 'mi', 'pca', 'rfe', 'shap']

results = []
saved_models = {}

for method in feature_methods:
    print(f"\n[{method.upper()} Method]")
    
    if method == 'all':
        X_train_sel = X_train.copy()
        X_test_sel = X_test.copy()
        
        model = TabPFNClassifier.create_default_for_version(ModelVersion.V2_5)
        model.fit(X_train_sel.values, y_train.values)
        
        pred = model.predict(X_test_sel.values)
        pred_proba = model.predict_proba(X_test_sel.values)
        
        f1 = f1_score(y_test, pred, average='weighted')
        auc = roc_auc_score(y_test, pred_proba[:, 1])
        
        print(f"  N_feat: {X_train.shape[1]:3d} (전체) - F1: {f1:.4f}, AUC: {auc:.4f}")
        
        saved_models[f'{method}_all'] = {
            'model': model,
            'method': method,
            'n_features': X_train.shape[1],
            'selected_features': list(X_train.columns),
            'transformer': None
        }
        
        results.append({
            'method': method,
            'n_features': X_train.shape[1],
            'f1': f1,
            'auc': auc,
            'model_key': f'{method}_all'
        })
    
    else:
        for n_feat in n_features_list:
            transformer = None
            features = None

            if method == 'random':
                np.random.seed(42)
                idx = np.random.choice(X_train.shape[1], n_feat, replace=False)
                features = X_train.columns[idx].tolist()
                X_train_sel = X_train[features]
                X_test_sel = X_test[features]
                
            elif method == 'mi':
                mi_scores = mutual_info_classif(X_train, y_train, random_state=42, n_jobs=-1)
                idx = np.argsort(mi_scores)[-n_feat:]
                features = X_train.columns[idx].tolist()
                X_train_sel = X_train[features]
                X_test_sel = X_test[features]
                
            elif method == 'pca':
                pca = PCA(n_components=n_feat, random_state=42)
                X_train_sel = pca.fit_transform(X_train)
                X_test_sel = pca.transform(X_test)
                transformer = pca
                
            elif method == 'rfe':
                rf_base = RandomForestClassifier(n_estimators=50, max_depth=10, random_state=42, n_jobs=-1)
                rfe = RFE(estimator=rf_base, n_features_to_select=n_feat, step=50, verbose=0)
                rfe.fit(X_train, y_train)
                features = X_train.columns[rfe.support_].tolist()
                X_train_sel = X_train[features]
                X_test_sel = X_test[features]
                transformer = rfe
                
            elif method == 'shap':
                rf_shap = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=42, n_jobs=-1)
                rf_shap.fit(X_train, y_train)
                
                sample_size = min(1000, X_train.shape[0])
                X_sample = X_train.sample(n=sample_size, random_state=42)
                
                explainer = shap.TreeExplainer(rf_shap)
                shap_values = explainer.shap_values(X_sample)
                
                shap_importance = np.abs(shap_values).mean(axis=0).mean(axis=1)
                idx = np.argsort(shap_importance)[-n_feat:]
                features = X_train.columns[idx].tolist()
                X_train_sel = X_train[features]
                X_test_sel = X_test[features]
            
            model = TabPFNClassifier.create_default_for_version(ModelVersion.V2_5)
            model.fit(X_train_sel, y_train.values)
            
            pred = model.predict(X_test_sel)
            pred_proba = model.predict_proba(X_test_sel)
            
            f1 = f1_score(y_test, pred, average='weighted')
            auc = roc_auc_score(y_test, pred_proba[:, 1])
            
            #print(f"  N_feat: {n_feat:3d} - F1: {f1:.4f}, AUC: {auc:.4f}")
            
            model_key = f'{method}_{n_feat}'
            saved_models[model_key] = {
                'model': model,
                'method': method,
                'n_features': n_feat,
                'selected_features': features,
                'transformer': transformer
            }
            
            results.append({
                'method': method,
                'n_features': n_feat,
                'f1': f1,
                'auc': auc,
                'model_key': model_key
            })

results_df = pd.DataFrame(results)
# Out:
# [ALL Method]
#   N_feat: 1040 (전체) - F1: 0.9642, AUC: 0.9761
#
# [RANDOM Method]
#
# [MI Method]
#
# [PCA Method]
#
# [RFE Method]
#
# [SHAP Method]

# %%
results_df.sort_values('f1', ascending=False).to_csv('../result/FTO_TABPFN/model_performance.csv')

# %% [markdown]
# ## 최고 성능 모델 (PCA 50) SHAP 분석

# %%
# 전체 데이터 준비
filtered_df = df[['potency'] + fp_cols + md_cols]
X = filtered_df.drop('potency', axis=1)
Y = filtered_df['potency']

X_train, X_test, y_train, y_test = train_test_split(
    X, Y, test_size=0.1, random_state=42, stratify=Y
)

# PCA 50 적용
print("\n1단계: PCA 50 features 추출")
pca = PCA(n_components=50, random_state=42)
X_train_pca = pca.fit_transform(X_train)
X_test_pca = pca.transform(X_test)

# TabPFN 학습
print("2단계: TabPFN 학습")
model_pca50 = TabPFNClassifier.create_default_for_version(ModelVersion.V2_5)
model_pca50.fit(X_train_pca, y_train.values)

# 성능 확인
pred = model_pca50.predict(X_test_pca)
pred_proba = model_pca50.predict_proba(X_test_pca)
f1 = f1_score(y_test, pred, average='weighted')
auc = roc_auc_score(y_test, pred_proba[:, 1])

print(f"\n[성능 확인] PCA 50")
print(f"  F1 Score:  {f1:.4f}")
print(f"  AUC Score: {auc:.4f}")

# ==================== SHAP 분석 ====================
print("\n3단계: SHAP 분석 (KernelExplainer 사용)")
print("  경고: 계산에 시간이 오래 걸립니다...")

# 샘플링 (전체 데이터는 너무 오래 걸림)
sample_size = min(100, X_test_pca.shape[0])  # 테스트 데이터에서 100개 샘플
X_sample = X_test_pca[:sample_size]
y_sample = y_test.values[:sample_size]

print(f"  - 분석 샘플: {sample_size}개")
print(f"  - Features: {X_sample.shape[1]}개 (PCA components)")

# KernelExplainer 생성
# TabPFN의 predict_proba를 사용하는 wrapper 함수
def model_predict(X):
    return model_pca50.predict_proba(X)

# Background 데이터 (더 작게 샘플링)
background_size = min(50, X_train_pca.shape[0])
X_background = X_train_pca[:background_size]

print(f"  - Background 데이터: {background_size}개")
print("\n  SHAP 계산 시작...")

# KernelExplainer 생성 및 SHAP values 계산
explainer = shap.KernelExplainer(model_predict, X_background)
shap_values = explainer.shap_values(X_sample, nsamples=100)  # nsamples 줄여서 속도 향상

print("  SHAP 계산 완료!")

# ==================== SHAP 시각화 ====================
print("\n4단계: SHAP 시각화")

# Class 1에 대한 SHAP values (binary classification이므로 [1] 사용)
if isinstance(shap_values, list):
    shap_values_class1 = shap_values[1]
else:
    shap_values_class1 = shap_values

# 1. Summary Plot
plt.figure(figsize=(12, 8))
shap.summary_plot(shap_values_class1, X_sample, 
                  feature_names=[f'PC{i+1}' for i in range(50)],
                  show=False, max_display=20)
plt.tight_layout()
plt.savefig(f'{result_dir}/shap_summary_plot.png', dpi=300, bbox_inches='tight')
plt.close()
print(f"  저장: shap_summary_plot.png")

# 2. Bar Plot (평균 절대값)
plt.figure(figsize=(10, 8))
shap.summary_plot(shap_values_class1, X_sample,
                  feature_names=[f'PC{i+1}' for i in range(50)],
                  plot_type='bar', show=False, max_display=20)
plt.tight_layout()
plt.savefig(f'{result_dir}/shap_bar_plot.png', dpi=300, bbox_inches='tight')
plt.close()
print(f"  저장: shap_bar_plot.png")

# 3. Feature Importance 저장
mean_abs_shap = np.abs(shap_values_class1).mean(axis=0)
feature_importance = pd.DataFrame({
    'feature': [f'PC{i+1}' for i in range(50)],
    'mean_abs_shap': mean_abs_shap
}).sort_values('mean_abs_shap', ascending=False)

feature_importance.to_csv(f'{result_dir}/shap_feature_importance.csv', index=False)
print(f"  저장: shap_feature_importance.csv")

# 4. PCA 성분과 원본 feature 매핑
# PCA components (원본 feature 기여도)
pca_components = pd.DataFrame(
    pca.components_,
    columns=X_train.columns,
    index=[f'PC{i+1}' for i in range(50)]
)
pca_components.to_csv(f'{result_dir}/pca_components.csv')
print(f"  저장: pca_components.csv")

# %% [markdown]
# ## MD only

# %%
# MD만 선택
filtered_df_md = df[['potency'] + md_cols]
X_md = filtered_df_md.drop('potency', axis=1)
Y_md = filtered_df_md['potency']

X_train_md, X_test_md, y_train_md, y_test_md = train_test_split(
    X_md, Y_md, test_size=0.1, random_state=42, stratify=Y_md
)

print(f"학습 데이터: {X_train_md.shape}, 테스트 데이터: {X_test_md.shape}")

# TabPFN 학습
model_md = TabPFNClassifier.create_default_for_version(ModelVersion.V2_5)
model_md.fit(X_train_md.values, y_train_md.values)

# 평가
pred_md = model_md.predict(X_test_md.values)
pred_proba_md = model_md.predict_proba(X_test_md.values)

f1_md = f1_score(y_test_md, pred_md, average='weighted')
auc_md = roc_auc_score(y_test_md, pred_proba_md[:, 1])

print(f"  F1 Score:  {f1_md:.4f}")
print(f"  AUC Score: {auc_md:.4f}")

# %% [markdown]
# ## 생성된 모델들로 예측하기

# %%
def predict_with_model_batched(model_key, new_data, training_columns, batch_size=500, verbose=False):
    model_info = saved_models[model_key]
    model = model_info['model']
    method = model_info['method']
    selected_features = model_info['selected_features']
    transformer = model_info['transformer']
    
    new_data_features = new_data[training_columns]
    
    n_samples = len(new_data_features)
    n_batches = (n_samples + batch_size - 1) // batch_size
    
    all_preds = []
    all_probas = []
    
    # 배치별 예측
    batch_iter = range(n_batches)
    if verbose:
        batch_iter = tqdm(batch_iter, desc=f"  {model_key}", leave=False)
    
    for i in batch_iter:
        start_idx = i * batch_size
        end_idx = min((i + 1) * batch_size, n_samples)
        batch_data = new_data_features.iloc[start_idx:end_idx]
        
        # Feature 변환
        if method == 'pca':
            batch_transformed = transformer.transform(batch_data)
        elif method == 'rfe':
            batch_transformed = batch_data[selected_features].values
        else:
            batch_transformed = batch_data[selected_features].values
        
        # 예측
        pred = model.predict(batch_transformed)
        pred_proba = model.predict_proba(batch_transformed)
        
        all_preds.append(pred)
        all_probas.append(pred_proba)
    
    # 결과 합치기
    final_pred = np.concatenate(all_preds)
    final_proba = np.vstack(all_probas)
    
    predictions = pd.DataFrame({
        'prediction': final_pred,
        'probability_class_0': final_proba[:, 0],
        'probability_class_1': final_proba[:, 1]
    })
    
    return predictions

# %%
'''def predict_with_model(model_key, new_data):
    model_info = saved_models[model_key]
    model = model_info['model']
    method = model_info['method']
    selected_features = model_info['selected_features']
    transformer = model_info['transformer']
    
    # Feature 선택
    if method == 'pca':
        new_data_transformed = transformer.transform(new_data)
    elif method == 'rfe':
        new_data_transformed = new_data[selected_features].values
    else:
        new_data_transformed = new_data[selected_features].values
    
    # 예측
    pred = model.predict(new_data_transformed)
    pred_proba = model.predict_proba(new_data_transformed)
    
    # 결과 정리
    predictions = pd.DataFrame({
        'prediction': pred,
        'probability_class_0': pred_proba[:, 0],
        'probability_class_1': pred_proba[:, 1]
    })
    
    return predictions'''

# %%
ratio = '10x'
foodb_df = pd.read_csv(f"../data/foodb/filtered_foodb_{ratio}.csv")

training_columns = X_train.columns.tolist()

print(f"FooDB 데이터 로드 완료")
print(f"  - 화합물 수: {len(foodb_df):,}개")
print(f"  - 컬럼 수: {len(foodb_df.columns)}개")
print(f"  - 메모리 사용: {foodb_df.memory_usage(deep=True).sum() / 1024**2:.2f} MB")
# Out:
# FooDB 데이터 로드 완료
#   - 화합물 수: 23,991개
#   - 컬럼 수: 1042개
#   - 메모리 사용: 194.41 MB

# %%
BATCH_SIZE = 500
output_dir = '../result/FTO_TABPFN'
os.makedirs(output_dir, exist_ok=True)

existing_files = set()
for f in os.listdir(output_dir):
    if f.endswith('_foodb_predictions.csv'):
        model_key = f.replace('_foodb_predictions.csv', '')
        existing_files.add(model_key)

models_to_predict = {k: v for k, v in saved_models.items() if k not in existing_files}

print(f"\n{'='*70}")
print(f"예측 시작 (스마트 캐싱)")
print(f"  - 전체 모델: {len(saved_models)}개")
print(f"  - 이미 완료: {len(existing_files)}개 ✓")
print(f"  - 예측 필요: {len(models_to_predict)}개")
print(f"{'='*70}\n")

if len(models_to_predict) == 0:
    print("모든 모델이 이미 완료되었습니다!")
else:
    all_predictions = {}
    model_stats = []
    total_start = time.time()
    
    for model_key in tqdm(models_to_predict.keys(), desc="전체 진행"):
        model_start = time.time()
        
        predictions = predict_with_model_batched(
            model_key, foodb_df, training_columns, 
            batch_size=BATCH_SIZE, verbose=False
        )
        
        all_predictions[model_key] = predictions
        
        n_class1 = sum(predictions['prediction'] == 1)
        n_class0 = sum(predictions['prediction'] == 0)
        elapsed = time.time() - model_start
        
        model_stats.append({
            'model': model_key,
            'class_0': n_class0,
            'class_1': n_class1,
            'ratio': f"{n_class1/(n_class0+n_class1)*100:.1f}%",
            'time_sec': elapsed
        })
        
        tqdm.write(f"[{model_key:15s}] 0: {n_class0:5d} | 1: {n_class1:5d} ({elapsed:.1f}초)")
        
        class1_mask = predictions['prediction'] == 1
        
        if class1_mask.sum() > 0:
            result_df = pd.DataFrame({
                'id': foodb_df.loc[class1_mask, 'id'].values,
                'canonical_SMILES': foodb_df.loc[class1_mask, 'canonical_SMILES'].values,
                'prediction': predictions.loc[class1_mask, 'prediction'].values,
                'probability': predictions.loc[class1_mask, 'probability_class_1'].values
            }).sort_values('probability', ascending=False).drop_duplicates('canonical_SMILES')
            
            csv_path = f'{output_dir}/{model_key}_foodb_predictions.csv'
            result_df.to_csv(csv_path, index=False)
        else:
            empty_df = pd.DataFrame(columns=['id', 'canonical_SMILES', 'prediction', 'probability'])
            csv_path = f'{output_dir}/{model_key}_foodb_predictions.csv'
            empty_df.to_csv(csv_path, index=False)
    
    total_elapsed = time.time() - total_start
    
    print(f"\n{'='*70}")
    print(f"✓ 완료: {total_elapsed:.1f}초 ({total_elapsed/60:.2f}분)")
    print(f"  - 전체: {len(saved_models)}개 (캐시 {len(existing_files)}개 포함)")
    print(f"{'='*70}")
# Out:
# ======================================================================
# 예측 시작 (스마트 캐싱)
#   - 전체 모델: 31개
#   - 이미 완료: 13개 ✓
#   - 예측 필요: 18개
# ======================================================================
# 전체 진행:   0%|          | 0/18 [00:00<?, ?it/s]
# [pca_50         ] 0: 23185 | 1:   806 (111.5초)
# [pca_100        ] 0: 23227 | 1:   764 (208.5초)
# [pca_200        ] 0: 23160 | 1:   831 (399.8초)
# [pca_300        ] 0: 23127 | 1:   864 (589.9초)
# [pca_400        ] 0: 23316 | 1:   675 (796.3초)
# [pca_500        ] 0: 23278 | 1:   713 (1045.4초)
# [rfe_50         ] 0: 23974 | 1:    17 (108.2초)
# [rfe_100        ] 0: 23977 | 1:    14 (206.2초)
# [rfe_200        ] 0: 23944 | 1:    47 (406.9초)
# [rfe_300        ] 0: 23954 | 1:    37 (597.0초)
# [rfe_400        ] 0: 23945 | 1:    46 (804.1초)
# [rfe_500        ] 0: 23958 | 1:    33 (1046.9초)
# [shap_50        ] 0: 23982 | 1:     9 (111.0초)
# [shap_100       ] 0: 23963 | 1:    28 (209.9초)
# [shap_200       ] 0: 23939 | 1:    52 (407.7초)
# [shap_300       ] 0: 23944 | 1:    47 (603.5초)
# [shap_400       ] 0: 23957 | 1:    34 (790.5초)
# [shap_500       ] 0: 23966 | 1:    25 (1040.8초)
#
# ======================================================================
# ✓ 완료: 9484.3초 (158.07분)
#   - 전체: 31개 (캐시 13개 포함)
# ======================================================================

# %%
stats_df = pd.DataFrame(model_stats)
stats_df.to_csv('../result/FTO_TABPFN/prediction_stats.csv', index=False)
stats_df
# Out:
#        model  class_0  class_1 ratio     time_sec
# 0     pca_50    23185      806  3.4%   111.531707
# 1    pca_100    23227      764  3.2%   208.486670
# 2    pca_200    23160      831  3.5%   399.785029
# 3    pca_300    23127      864  3.6%   589.900936
# 4    pca_400    23316      675  2.8%   796.345227
# 5    pca_500    23278      713  3.0%  1045.364933
# 6     rfe_50    23974       17  0.1%   108.216447
# 7    rfe_100    23977       14  0.1%   206.225078
# 8    rfe_200    23944       47  0.2%   406.944875
# 9    rfe_300    23954       37  0.2%   596.980356
# 10   rfe_400    23945       46  0.2%   804.081331
# 11   rfe_500    23958       33  0.1%  1046.938295
# 12   shap_50    23982        9  0.0%   110.958179
# 13  shap_100    23963       28  0.1%   209.866182
# 14  shap_200    23939       52  0.2%   407.700085
# 15  shap_300    23944       47  0.2%   603.480121
# 16  shap_400    23957       34  0.1%   790.497220
# 17  shap_500    23966       25  0.1%  1040.839151
